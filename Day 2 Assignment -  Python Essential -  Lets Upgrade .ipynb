# %% [markdown]
# # Basic Python Syntax

# %% [markdown]
# BACK SLASH

# %%
print("Hello \
python")
# Out:
# Hello python

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("python world")
# Out:
# python world

# %% [markdown]
# TIPLE QUOTES

# %%
print("""  Hello Every one"""
     )
# Out:
#   Hello Every one

# %%
print( """    / / / / / / / / /
/ / / / / / / / /
__,____,       
/____,_/ \ .;';';.
,l__[]__,l_! ,,)(,,
- - - - - -  """
     )
# Out:
#     / / / / / / / / /
# / / / / / / / / /
# __,____,
# /____,_/ \ .;';';.
# ,l__[]__,l_! ,,)(,,
# - - - - - -

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("python's world")
# Out:
# python's world

# %% [markdown]
# STRING INSIDE THE QUOTE

# %%
print("hello\tpython")
# Out:
# hello	python

# %%
print('python\'s world')
# Out:
# python's world

# %%
print("hello\apython")
# Out:
# hellopython

# %% [markdown]
# FORMATTED OUTPUT

# %%
name="Archana"
marks="90.87"
age="20"
print("The name of person is ", name, "mark is ", marks, "age is", age)
# Out:
# The name of person is  Archana mark is  90.87 age is 20

# %%
print("The name of person is %s  marks is %f  age is %d"%(name,marks,age) )
# Out:
# ----------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-52-a0cc6e7eb296> in <module>
# ----> 1 print("The name of person is %s  marks is %f  age is %d"%(name,marks,age) )
#
# TypeError: must be real number, not str

# %%
print(f"the name of perosn is {name} the marks{marks} is age is {age}")
# Out:
# the name of perosn is Archana the marks90.87 is age is 20

# %%
Varibale

# %%
if1= 10

# %%
_10=6

# %% [markdown]
# Python Assignment Statement

# %%
x = y = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
x = 20

# %%
id(x)
# Out:
# 140735067104240

# %%
y = 20

# %%
id(y)
# Out:
# 140735067104240

# %%
del x
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-68-52e2ca59f643> in <module>
# ----> 1 del x
#
# NameError: name 'x' is not defined

# %%
id(x)
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-69-e3f71ffdf578> in <module>
# ----> 1 id(x)
#
# NameError: name 'x' is not defined

# %%
id(y)
# Out:
# 140735067104240

# %%
del y

# %%
id(y)
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-72-e6babe6803e1> in <module>
# ----> 1 id(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# ASSIGNMENT OPERATOR

# %%
5**5
# Out:
# 3125

# %%
9**9
# Out:
# 387420489

# %%
11**14
# Out:
# 379749833583241

# %%
10+20
# Out:
# 30

# %%
10/2
# Out:
# 5.0

# %%
10-20
# Out:
# -10

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
10//3
# Out:
# 3

# %%
11*14
# Out:
# 154

# %% [markdown]
# Comparison Operator

# %%
a = 10
b= 20
a == b
# Out:
# False

# %%
c= 10
a == c
# Out:
# True

# %%
c < a
# Out:
# False

# %%
 c <= a
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a!=b
# Out:
# True

# %% [markdown]
# BITWISE OPERATOR

# %%
a=240

# %%
b=1

# %%
a|b
# Out:
# 11

# %%
a&b
# Out:
# 0

# %% [markdown]
# Logical Operator

# %%
a=1

# %%
b = 20

# %%
a>20
# Out:
# False

# %%
a>20 or 10 > 9
# Out:
# True

# %%
10 > 9 and 20 > M
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-99-517b899b743b> in <module>
# ----> 1 10 > 9 and 20 > M
#
# NameError: name 'M' is not defined

# %%
10<9 and 20>M
# Out:
# False

# %%
not 10 < 9
# Out:
# True

# %% [markdown]
# MEMBERSHIP OPERATOR

# %%
strl = "pythonprogramming"
"a" in strl
# Out:
# True

# %%
strl = "pythonprogramming"
"x" in strl
# Out:
# False

# %%
strl = "pythonprogramming"
"x" not in strl
# Out:
# True

# %%
IDENTITY OPERATOR

# %%
a = 10
b = 10
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 140735067103920

# %%
id(b)
# Out:
# 140735067103920

# %%
x=1.5
y=1.5
x == y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
id(x)
# Out:
# 2154832919856

# %%
id(y)
# Out:
# 2154832919792

# %%
10+10/29*4
# Out:
# 11.379310344827587

# %%
10/29
# Out:
# 0.3448275862068966

# %%
2**-1
# Out:
# 0.5
